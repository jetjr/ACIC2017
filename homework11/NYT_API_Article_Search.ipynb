# %%
import requests
import json

search = ['mars', 'earth', "mercury"]

for i in search:
    print(i)
    url = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q={}&api-key=a3597c6a331f490abe9b72f1b9614979'.format(i)
    r = requests.get(url)
    x = r.json()
    print(x)
# Out:
# mars
# ...

# %%
# Title
